# %%
import pandas as pd

# %%
data = pd.read_csv(r"padded_urls.csv")

# %%
data.head()
# Out:
#                                                  url  label  \
# 0  http://007indien.blogspot.com/2013/08/daftar-l...      0
# 1                          http://021jiaju.com/xhsd/      0
# 2     http://03.rospotrebnadzor.ru/content/336/9833/      0
# 3           http://039.holidayblog.jp/?cat=7&paged=2      0
# 4  http://03online.com/news/boli_vnizu_zhivota_za...      0
#
#                                          padded_urls
# 0  http://007indien.blogspot.com/2013/08/daftar-l...
# 1  http://021jiaju.com/xhsd/~~~~~~~~~~~~~~~~~~~~~...
# 2  http://03.rospotrebnadzor.ru/content/336/9833/...
# 3  http://039.holidayblog.jp/?cat=7&paged=2~~~~~~...
# 4  http://03online.com/news/boli_vnizu_zhivota_za...

# %%
urls = data.iloc[:,2]

# %%
print(urls)
# Out:
# 0        http://007indien.blogspot.com/2013/08/daftar-l...
# 1        http://021jiaju.com/xhsd/~~~~~~~~~~~~~~~~~~~~~...
# 2        http://03.rospotrebnadzor.ru/content/336/9833/...
# 3        http://039.holidayblog.jp/?cat=7&paged=2~~~~~~...
# 4        http://03online.com/news/boli_vnizu_zhivota_za...
#                                ...
# 20123    http://click.partner.roamans.com/c6/7310437653...
# 20124    https://click.securedvisit.com/c6/7310437653_6...
# 20125    http://click.partner.roamans.com/c6/7310437653...
# 20126    https://www.roamans.com/?affiliate_id=054&affi...
# 20127    https://click.securedvisit.com/c6/7310437653_6...
# Name: padded_urls, Length: 20128, dtype: object

# %%
dictionary = "abcdefghijklmnopqrstuvwxyz0123456789`~!@#$%^&*()-_=+[{}]|;\:',<.>/\"? "

file = 1
index_label = 0
label = []
for url in urls:
    rows , cols = (len(dictionary), len(url))
    print(rows, cols)
    arr = [[0 for i in range(cols)] for j in range(rows)]
    
    for i in range(0, len(dictionary)):
        for j in range(0,len(url)):
#             print(dic[i] , str[j])
            if(dictionary[i]==url[j]):
                arr[i][j] = "1"
            
            else:
                arr[i][j] = "0"
        
   
    df = pd.DataFrame(arr)
   
   


#     df["label"] = " "
   
#     for i in range(70):
#         if(labels[index_label] == 0):
#             df["label"][i] = "0"
#         else:
#             df["label"][i] = "1"
#     index_label+=1
# df.head()
#     print(df.head())
    df.to_csv("url_data/image_{0}.csv".format(file))
    file+=1
# Out:
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# 69 256
# ...
